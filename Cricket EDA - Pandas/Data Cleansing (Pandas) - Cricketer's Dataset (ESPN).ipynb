# %% [markdown]
# # Data Cleansing the Cricketer's Dataset (ESPN)

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("C:\\Users\\kondu\\OneDrive\\Desktop\\Projects\\Pandas\\Cricket EDA - Pandas\\Cricketers Dataset.csv")
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 3      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 4     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 63  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 64  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 65    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 66   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %% [raw]
# # renaming the columns

# %%
df = df.rename(columns={'NO':'Not_Outs','HS':'High_Score','Ave':'Average','BF':'Balls_Faced','SR':'Strike_Rate','0':'duck'})
df
# Out:
#                Player       Span  Mat  Inns  Not_Outs  Runs High_Score  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996        334
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181        186
# 2      HC Brook (ENG)  2022-2023   12    20         1  1181        186
# 3      AC Voges (AUS)  2015-2016   20    31         7  1485       269*
# 4     RG Pollock (SA)  1963-1970   23    41         4  2256        274
# ..                ...        ...  ...   ...       ...   ...        ...
# 62   KD Walters (AUS)  1965-1981   74   125        14  5357        250
# 63  GC Smith (ICC/SA)  2002-2014  117   205        13  9265        277
# 64  WH Ponsford (AUS)  1924-1934   29    48         4  2122        266
# 65    SJ McCabe (AUS)  1930-1938   39    62         5  2748        232
# 66   DR Jardine (ENG)  1928-1934   22    33         6  1296        127
#
#     Average Balls_Faced  Strike_Rate  100  50  duck    4s  6s
# ...

# %% [raw]
# # checking for null values

# %%
df.isnull().any()
# Out:
# Player         False
# Span           False
# Mat            False
# Inns           False
# Not_Outs       False
# Runs           False
# High_Score     False
# Average        False
# Balls_Faced     True
# Strike_Rate     True
# 100            False
# 50             False
# duck           False
# 4s             False
# 6s             False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1] 
df[df['Strike_Rate'].isna()==1]
# Out:
#                   Player       Span  Mat  Inns  Not_Outs  Runs High_Score  \
# 9         ED Weekes (WI)  1948-1958   48    81         5  4455        207
# 16       CL Walcott (WI)  1948-1960   44    74         7  3798        220
# 59  Hon.FS Jackson (ENG)  1893-1905   20    33         4  1415       144*
#
#     Average Balls_Faced  Strike_Rate  100  50  duck   4s  6s
# 9     58.61         NaN          NaN   15  19     6  258   2
# 16    56.68         NaN          NaN   15  14     1  107  11
# 59    48.79         NaN          NaN    5   6     3   51   0

# %%
#replacing na with '0'

df['Balls_Faced']=df['Balls_Faced'].fillna(0)
df['Strike_Rate']=df['Strike_Rate'].fillna(0)

# %%
# checking if na present or not

df[df['Balls_Faced'].isna()==1] 
df[df['Strike_Rate'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Mat, Inns, Not_Outs, Runs, High_Score, Average, Balls_Faced, Strike_Rate, 100, 50, duck, 4s, 6s]
# Index: []

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not_Outs  Runs High_Score  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996        334
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181        186
# 2      HC Brook (ENG)  2022-2023   12    20         1  1181        186
# 3      AC Voges (AUS)  2015-2016   20    31         7  1485       269*
# 4     RG Pollock (SA)  1963-1970   23    41         4  2256        274
# ..                ...        ...  ...   ...       ...   ...        ...
# 62   KD Walters (AUS)  1965-1981   74   125        14  5357        250
# 63  GC Smith (ICC/SA)  2002-2014  117   205        13  9265        277
# 64  WH Ponsford (AUS)  1924-1934   29    48         4  2122        266
# 65    SJ McCabe (AUS)  1930-1938   39    62         5  2748        232
# 66   DR Jardine (ENG)  1928-1934   22    33         6  1296        127
#
#     Average Balls_Faced  Strike_Rate  100  50  duck    4s  6s
# ...

# %% [raw]
# # removing duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# Length: 67, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                 Player       Span  Mat  Inns  Not_Outs  Runs High_Score  \
# 2       HC Brook (ENG)  2022-2023   12    20         1  1181        186
# 21  KS Williamson (NZ)  2010-2023   94   164        16  8124        251
# 54       V Kohli (IND)  2011-2023  111   187        11  8676       254*
#
#     Average Balls_Faced  Strike_Rate  100  50  duck   4s  6s
# 2     62.15        1287        91.76    4   7     1  141  23
# 21    54.89       15785        51.46   28  33    10  897  21
# 54    49.29       15708        55.23   29  29    14  966  24

# %%
df[df['Player'].isin(['HC Brook (ENG)','KS Williamson (NZ)','V Kohli (IND)'])]
# Out:
#                 Player       Span  Mat  Inns  Not_Outs  Runs High_Score  \
# 1       HC Brook (ENG)  2022-2023   12    20         1  1181        186
# 2       HC Brook (ENG)  2022-2023   12    20         1  1181        186
# 20  KS Williamson (NZ)  2010-2023   94   164        16  8124        251
# 21  KS Williamson (NZ)  2010-2023   94   164        16  8124        251
# 53       V Kohli (IND)  2011-2023  111   187        11  8676       254*
# 54       V Kohli (IND)  2011-2023  111   187        11  8676       254*
#
#     Average Balls_Faced  Strike_Rate  100  50  duck   4s  6s
# 1     62.15        1287        91.76    4   7     1  141  23
# 2     62.15        1287        91.76    4   7     1  141  23
# 20    54.89       15785        51.46   28  33    10  897  21
# 21    54.89       15785        51.46   28  33    10  897  21
# 53    49.29       15708        55.23   29  29    14  966  24
# 54    49.29       15708        55.23   29  29    14  966  24

# %%
df=df.drop_duplicates()

# %%
df[df['Player'].isin(['HC Brook (ENG)','KS Williamson (NZ)','V Kohli (IND)'])]
# Out:
#                 Player       Span  Mat  Inns  Not_Outs  Runs High_Score  \
# 1       HC Brook (ENG)  2022-2023   12    20         1  1181        186
# 20  KS Williamson (NZ)  2010-2023   94   164        16  8124        251
# 53       V Kohli (IND)  2011-2023  111   187        11  8676       254*
#
#     Average Balls_Faced  Strike_Rate  100  50  duck   4s  6s
# 1     62.15        1287        91.76    4   7     1  141  23
# 20    54.89       15785        51.46   28  33    10  897  21
# 53    49.29       15708        55.23   29  29    14  966  24

# %% [raw]
# # Splitting Span column into Start_Yr and End_Yr

# %%
df['Span']
# Out:
# 0     1928-1948
# 1     2022-2023
# 3     2015-2016
# 4     1963-1970
# 5     1930-1954
#         ...
# 62    1965-1981
# 63    2002-2014
# 64    1924-1934
# 65    1930-1938
# 66    1928-1934
# Name: Span, Length: 64, dtype: object

# %%
df['Span'].str.split(pat='-').str[0]
# Out:
# 0     1928
# 1     2022
# 3     2015
# 4     1963
# 5     1930
#       ...
# 62    1965
# 63    2002
# 64    1924
# 65    1930
# 66    1928
# Name: Span, Length: 64, dtype: object

# %%
df['Start_Yr']=df['Span'].str.split(pat='-').str[0]
# Out:
# C:\Users\kondu\AppData\Local\Temp\ipykernel_17804\4156645703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start_Yr']=df['Span'].str.split(pat='-').str[0]

# %%
df['End_Yr']=df['Span'].str.split(pat='-').str[1]
# Out:
# C:\Users\kondu\AppData\Local\Temp\ipykernel_17804\1578911166.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['End_Yr']=df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not_Outs  Runs High_Score  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996        334
# 1      HC Brook (ENG)  2022-2023   12    20         1  1181        186
# 3      AC Voges (AUS)  2015-2016   20    31         7  1485       269*
# 4     RG Pollock (SA)  1963-1970   23    41         4  2256        274
# 5     GA Headley (WI)  1930-1954   22    40         4  2190       270*
# ..                ...        ...  ...   ...       ...   ...        ...
# 62   KD Walters (AUS)  1965-1981   74   125        14  5357        250
# 63  GC Smith (ICC/SA)  2002-2014  117   205        13  9265        277
# 64  WH Ponsford (AUS)  1924-1934   29    48         4  2122        266
# 65    SJ McCabe (AUS)  1930-1938   39    62         5  2748        232
# 66   DR Jardine (ENG)  1928-1934   22    33         6  1296        127
#
#     Average Balls_Faced  Strike_Rate  100  50  duck    4s  6s Start_Yr End_Yr
# ...

# %%
#dropping Span column

# %%
df.drop(['Span'],axis=1)
# Out:
#                Player  Mat  Inns  Not_Outs  Runs High_Score  Average  \
# 0    DG Bradman (AUS)   52    80        10  6996        334    99.94
# 1      HC Brook (ENG)   12    20         1  1181        186    62.15
# 3      AC Voges (AUS)   20    31         7  1485       269*    61.87
# 4     RG Pollock (SA)   23    41         4  2256        274    60.97
# 5     GA Headley (WI)   22    40         4  2190       270*    60.83
# ..                ...  ...   ...       ...   ...        ...      ...
# 62   KD Walters (AUS)   74   125        14  5357        250    48.26
# 63  GC Smith (ICC/SA)  117   205        13  9265        277    48.25
# 64  WH Ponsford (AUS)   29    48         4  2122        266    48.22
# 65    SJ McCabe (AUS)   39    62         5  2748        232    48.21
# 66   DR Jardine (ENG)   22    33         6  1296        127    48.00
#
#    Balls_Faced  Strike_Rate  100  50  duck    4s  6s Start_Yr End_Yr
# 0        9800+        58.60   29  13     7   626   6     1928   1948
# ...

# %%
df=df.drop(['Span'],axis=1)

# %%
df.head()
# Out:
#              Player  Mat  Inns  Not_Outs  Runs High_Score  Average  \
# 0  DG Bradman (AUS)   52    80        10  6996        334    99.94
# 1    HC Brook (ENG)   12    20         1  1181        186    62.15
# 3    AC Voges (AUS)   20    31         7  1485       269*    61.87
# 4   RG Pollock (SA)   23    41         4  2256        274    60.97
# 5   GA Headley (WI)   22    40         4  2190       270*    60.83
#
#   Balls_Faced  Strike_Rate  100  50  duck   4s  6s Start_Yr End_Yr
# 0       9800+        58.60   29  13     7  626   6     1928   1948
# 1        1287        91.76    4   7     1  141  23     2022   2023
# 3        2667        55.68    5   4     2  186   5     2015   2016
# 4       1707+        54.48    7  11     1  246  11     1963   1970
# 5        416+        56.00   10   5     2  104   1     1930   1954

# %% [raw]
# # dividing player based on country

# %%
df['Player'].str.split(pat='(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 3        [AC Voges , AUS)]
# 4       [RG Pollock , SA)]
# 5       [GA Headley , WI)]
#               ...
# 62     [KD Walters , AUS)]
# 63    [GC Smith , ICC/SA)]
# 64    [WH Ponsford , AUS)]
# 65      [SJ McCabe , AUS)]
# 66     [DR Jardine , ENG)]
# Name: Player, Length: 64, dtype: object

# %%
df['country']=df['Player'].str.split(pat='(').str[1]

# %%
df['country'].str.split(pat=')')
# Out:
# 0        [AUS, ]
# 1        [ENG, ]
# 3        [AUS, ]
# 4         [SA, ]
# 5         [WI, ]
#          ...
# 62       [AUS, ]
# 63    [ICC/SA, ]
# 64       [AUS, ]
# 65       [AUS, ]
# 66       [ENG, ]
# Name: country, Length: 64, dtype: object

# %%
df['country']=df['country'].str.split(pat=')').str[0]
df.head()
# Out:
#              Player  Mat  Inns  Not_Outs  Runs High_Score  Average  \
# 0  DG Bradman (AUS)   52    80        10  6996        334    99.94
# 1    HC Brook (ENG)   12    20         1  1181        186    62.15
# 3    AC Voges (AUS)   20    31         7  1485       269*    61.87
# 4   RG Pollock (SA)   23    41         4  2256        274    60.97
# 5   GA Headley (WI)   22    40         4  2190       270*    60.83
#
#   Balls_Faced  Strike_Rate  100  50  duck   4s  6s Start_Yr End_Yr country
# 0       9800+        58.60   29  13     7  626   6     1928   1948     AUS
# 1        1287        91.76    4   7     1  141  23     2022   2023     ENG
# 3        2667        55.68    5   4     2  186   5     2015   2016     AUS
# 4       1707+        54.48    7  11     1  246  11     1963   1970      SA
# 5        416+        56.00   10   5     2  104   1     1930   1954      WI

# %%
df['Player'].str.split(pat='(').str[0]
# Out:
# 0      DG Bradman
# 1        HC Brook
# 3        AC Voges
# 4      RG Pollock
# 5      GA Headley
#           ...
# 62     KD Walters
# 63       GC Smith
# 64    WH Ponsford
# 65      SJ McCabe
# 66     DR Jardine
# Name: Player, Length: 64, dtype: object

# %%
df['Player']=df['Player'].str.split(pat='(').str[0]
df.head()
# Out:
#         Player  Mat  Inns  Not_Outs  Runs High_Score  Average Balls_Faced  \
# 0  DG Bradman    52    80        10  6996        334    99.94       9800+
# 1    HC Brook    12    20         1  1181        186    62.15        1287
# 3    AC Voges    20    31         7  1485       269*    61.87        2667
# 4  RG Pollock    23    41         4  2256        274    60.97       1707+
# 5  GA Headley    22    40         4  2190       270*    60.83        416+
#
#    Strike_Rate  100  50  duck   4s  6s Start_Yr End_Yr country
# 0        58.60   29  13     7  626   6     1928   1948     AUS
# 1        91.76    4   7     1  141  23     2022   2023     ENG
# 3        55.68    5   4     2  186   5     2015   2016     AUS
# 4        54.48    7  11     1  246  11     1963   1970      SA
# 5        56.00   10   5     2  104   1     1930   1954      WI

# %%
df['Balls_Faced'].str.split(pat='+')
# Out:
# 0     [9800, ]
# 1       [1287]
# 3       [2667]
# 4     [1707, ]
# 5      [416, ]
#         ...
# 62    [8662, ]
# 63     [15525]
# 64    [3118, ]
# 65    [3217, ]
# 66    [2110, ]
# Name: Balls_Faced, Length: 64, dtype: object

# %%
df['Balls_Faced']=df['Balls_Faced'].str.split(pat='+').str[0]
df.head()
# Out:
#         Player  Mat  Inns  Not_Outs  Runs High_Score  Average Balls_Faced  \
# 0  DG Bradman    52    80        10  6996        334    99.94        9800
# 1    HC Brook    12    20         1  1181        186    62.15        1287
# 3    AC Voges    20    31         7  1485       269*    61.87        2667
# 4  RG Pollock    23    41         4  2256        274    60.97        1707
# 5  GA Headley    22    40         4  2190       270*    60.83         416
#
#    Strike_Rate  100  50  duck   4s  6s Start_Yr End_Yr country
# 0        58.60   29  13     7  626   6     1928   1948     AUS
# 1        91.76    4   7     1  141  23     2022   2023     ENG
# 3        55.68    5   4     2  186   5     2015   2016     AUS
# 4        54.48    7  11     1  246  11     1963   1970      SA
# 5        56.00   10   5     2  104   1     1930   1954      WI

# %%
df['High_Score'].str.split(pat='*')
# Out:
# 0       [334]
# 1       [186]
# 3     [269, ]
# 4       [274]
# 5     [270, ]
#        ...
# 62      [250]
# 63      [277]
# 64      [266]
# 65      [232]
# 66      [127]
# Name: High_Score, Length: 64, dtype: object

# %%
df['High_Score']=df['High_Score'].str.split(pat='*').str[0]

# %%
df.head()
# Out:
#         Player  Mat  Inns  Not_Outs  Runs High_Score  Average Balls_Faced  \
# 0  DG Bradman    52    80        10  6996        334    99.94        9800
# 1    HC Brook    12    20         1  1181        186    62.15        1287
# 3    AC Voges    20    31         7  1485        269    61.87        2667
# 4  RG Pollock    23    41         4  2256        274    60.97        1707
# 5  GA Headley    22    40         4  2190        270    60.83         416
#
#    Strike_Rate  100  50  duck   4s  6s Start_Yr End_Yr country
# 0        58.60   29  13     7  626   6     1928   1948     AUS
# 1        91.76    4   7     1  141  23     2022   2023     ENG
# 3        55.68    5   4     2  186   5     2015   2016     AUS
# 4        54.48    7  11     1  246  11     1963   1970      SA
# 5        56.00   10   5     2  104   1     1930   1954      WI

# %%
#DataTypes

# %%
df.dtypes
# Out:
# Player          object
# Mat              int64
# Inns             int64
# Not_Outs         int64
# Runs             int64
# High_Score      object
# Average        float64
# Balls_Faced     object
# Strike_Rate    float64
# 100              int64
# 50               int64
# duck             int64
# 4s               int64
# 6s               int64
# Start_Yr        object
# End_Yr          object
# country         object
# dtype: object

# %%
df=df.astype({'High_Score':'int','Balls_Faced':'int','Start_Yr':'int','End_Yr':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 df=df.astype({'High_Score':'int','Balls_Faced':'int','Start_Yr':'int','End_Yr':'int'})
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6305, in NDFrame.astype(self, dtype, copy, errors)
#    6303 else:
#    6304     try:
# -> 6305         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6306     except ValueError as ex:
#    6307         ex.args = (
#    6308             f"{ex}: Error while type casting for column '{col_name}'",
#    6309         )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
# ...

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player  Mat  Inns  Not_Outs  Runs High_Score  Average  \
# 9        ED Weekes    48    81         5  4455        207    58.61
# 16      CL Walcott    44    74         7  3798        220    56.68
# 59  Hon.FS Jackson    20    33         4  1415        144    48.79
#
#    Balls_Faced  Strike_Rate  100  50  duck   4s  6s Start_Yr End_Yr country
# 9          NaN          0.0   15  19     6  258   2     1948   1958      WI
# 16         NaN          0.0   15  14     1  107  11     1948   1960      WI
# 59         NaN          0.0    5   6     3   51   0     1893   1905     ENG

# %%
df['Balls_Faced'].fillna(0)
# Out:
# 0      9800.0
# 1      1287.0
# 3      2667.0
# 4      1707.0
# 5       416.0
#        ...
# 62     8662.0
# 63    15525.0
# 64     3118.0
# 65     3217.0
# 66     2110.0
# Name: Balls_Faced, Length: 64, dtype: float64

# %%
df['Balls_Faced']=df['Balls_Faced'].fillna(0)

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Mat, Inns, Not_Outs, Runs, High_Score, Average, Balls_Faced, Strike_Rate, 100, 50, duck, 4s, 6s, Start_Yr, End_Yr, country]
# Index: []

# %%
df.head()
# Out:
#         Player  Mat  Inns  Not_Outs  Runs High_Score  Average Balls_Faced  \
# 0  DG Bradman    52    80        10  6996        334    99.94        9800
# 1    HC Brook    12    20         1  1181        186    62.15        1287
# 3    AC Voges    20    31         7  1485        269    61.87        2667
# 4  RG Pollock    23    41         4  2256        274    60.97        1707
# 5  GA Headley    22    40         4  2190        270    60.83         416
#
#    Strike_Rate  100  50  duck   4s  6s Start_Yr End_Yr country
# 0        58.60   29  13     7  626   6     1928   1948     AUS
# 1        91.76    4   7     1  141  23     2022   2023     ENG
# 3        55.68    5   4     2  186   5     2015   2016     AUS
# 4        54.48    7  11     1  246  11     1963   1970      SA
# 5        56.00   10   5     2  104   1     1930   1954      WI

# %%
df.dtypes
# Out:
# Player          object
# Mat              int64
# Inns             int64
# Not_Outs         int64
# Runs             int64
# High_Score      object
# Average        float64
# Balls_Faced     object
# Strike_Rate    float64
# 100              int64
# 50               int64
# duck             int64
# 4s               int64
# 6s               int64
# Start_Yr        object
# End_Yr          object
# country         object
# dtype: object

# %%
df['Balls_Faced']=df['Balls_Faced'].astype('int')
df.dtypes
# Out:
# Player          object
# Mat              int64
# Inns             int64
# Not_Outs         int64
# Runs             int64
# High_Score      object
# Average        float64
# Balls_Faced      int32
# Strike_Rate    float64
# 100              int64
# 50               int64
# duck             int64
# 4s               int64
# 6s               int64
# Start_Yr        object
# End_Yr          object
# country         object
# dtype: object

# %%
df=df.astype({'Start_Yr':'int','End_Yr':'int'})

# %%
df.dtypes
# Out:
# Player          object
# Mat              int64
# Inns             int64
# Not_Outs         int64
# Runs             int64
# High_Score      object
# Average        float64
# Balls_Faced      int32
# Strike_Rate    float64
# 100              int64
# 50               int64
# duck             int64
# 4s               int64
# 6s               int64
# Start_Yr         int32
# End_Yr           int32
# country         object
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#                 Player  Mat  Inns  Not_Outs   Runs High_Score  Average  \
# 0          DG Bradman    52    80        10   6996        334    99.94
# 1            HC Brook    12    20         1   1181        186    62.15
# 3            AC Voges    20    31         7   1485        269    61.87
# 4          RG Pollock    23    41         4   2256        274    60.97
# 5          GA Headley    22    40         4   2190        270    60.83
# 6         H Sutcliffe    54    84         9   4555        194    60.73
# 7           E Paynter    20    31         5   1540        243    59.23
# 8       KF Barrington    82   131        15   6806        256    58.67
# 9           ED Weekes    48    81         5   4455        207    58.61
# 10          SPD Smith   102   181        22   9320        239    58.61
# 11         WR Hammond    85   140        16   7249        336    58.45
# 12          GS Sobers    93   160        21   8032        365    57.78
# ...

# %%
#Question:
# What is the Career Length of the players?

# %%
df['Career_Length']=df['End_Yr']-df['Start_Yr']
df.head()
# Out:
#         Player  Mat  Inns  Not_Outs  Runs High_Score  Average  Balls_Faced  \
# 0  DG Bradman    52    80        10  6996        334    99.94         9800
# 1    HC Brook    12    20         1  1181        186    62.15         1287
# 3    AC Voges    20    31         7  1485        269    61.87         2667
# 4  RG Pollock    23    41         4  2256        274    60.97         1707
# 5  GA Headley    22    40         4  2190        270    60.83          416
#
#    Strike_Rate  100  50  duck   4s  6s  Start_Yr  End_Yr country  \
# 0        58.60   29  13     7  626   6      1928    1948     AUS
# 1        91.76    4   7     1  141  23      2022    2023     ENG
# 3        55.68    5   4     2  186   5      2015    2016     AUS
# 4        54.48    7  11     1  246  11      1963    1970      SA
# 5        56.00   10   5     2  104   1      1930    1954      WI
#
#    Career_Length
# 0             20
# 1              1
# 3              1
# 4              7
# 5             24

# %%
# What is the Average Career Length

# %%
df['Career_Length'].mean()
# Out:
# 12.75

# %%
#Avg batting strike rate of players who played more than 10yrs

# %%
df[df['Career_Length']>10]['Strike_Rate'].mean()
# Out:
# 47.95454545454545

# %%
# Total players who started playing before 1960

# %%
df[df['Start_Yr']<1960]['Player'].count()
# Out:
# 23

# %%
# highest innings score by a country

# %%
df.groupby('country')['High_Score'].min().to_frame('HighestScore').reset_index().sort_values('HighestScore',ascending=False)
# Out:
#     country HighestScore
# 5    ICC/WI          400
# 3   ICC/PAK          329
# 2   ICC/IND          270
# 12      ZIM          232
# 10       SL          231
# 6       IND          227
# 4    ICC/SA          224
# 8       PAK          201
# 0       AUS          195
# 7        NZ          190
# 11       WI          183
# 9        SA          144
# 1       ENG          122

# %%
#avg 100's,50's,duck by countries

# %%
df.groupby('country')[['100','50','duck']].mean().sort_values('duck',ascending=True)
# Out:
#                100         50       duck
# country
# SA        9.800000  20.200000   3.400000
# ENG      12.307692  20.769231   4.307692
# NZ       12.333333  16.333333   4.333333
# ZIM      12.000000  27.000000   5.000000
# WI       16.625000  25.625000   7.250000
# PAK      17.800000  23.200000   8.000000
# AUS      20.625000  28.000000   8.500000
# IND      29.500000  36.250000  10.750000
# ICC/IND  29.500000  47.500000  12.000000
# SL       28.666667  44.000000  12.333333
# ICC/SA   36.000000  48.000000  13.500000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/WI   34.000000  48.000000  17.000000
